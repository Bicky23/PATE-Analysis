# %%
## import libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
from torchvision import datasets
import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
from torch.utils.data import Subset
from torch import optim
# !pip install syft
import torch.nn.functional as F
from syft.frameworks.torch.differential_privacy import pate
import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: syft in /usr/local/lib/python3.6/dist-packages (0.1.18)
# Requirement already satisfied: torch>=1.1 in /usr/local/lib/python3.6/dist-packages (from syft) (1.1.0)
# Requirement already satisfied: tf-encrypted>=0.5.4 in /usr/local/lib/python3.6/dist-packages (from syft) (0.5.5)
# Requirement already satisfied: websockets>=7.0 in /usr/local/lib/python3.6/dist-packages (from syft) (7.0)
# Requirement already satisfied: zstd in /usr/local/lib/python3.6/dist-packages (from syft) (1.4.0.0)
# Requirement already satisfied: Flask in /usr/local/lib/python3.6/dist-packages (from syft) (1.0.3)
# Requirement already satisfied: tblib in /usr/local/lib/python3.6/dist-packages (from syft) (1.4.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.6/dist-packages (from syft) (0.5.6)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.6/dist-packages (from syft) (2.1.10)
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from syft) (0.3.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.6/dist-packages (from syft) (0.56.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from syft) (0.0)
# Requirement already satisfied: flask-socketio in /usr/local/lib/python3.6/dist-packages (from syft) (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.1->syft) (1.16.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted>=0.5.4->syft) (5.1.1)
# Requirement already satisfied: tensorflow<2,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tf-encrypted>=0.5.4->syft) (1.14.0rc1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask->syft) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask->syft) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask->syft) (0.15.4)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask->syft) (2.10.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->syft) (4.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->syft) (1.12.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->syft) (0.21.2)
# Requirement already satisfied: python-socketio>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from flask-socketio->syft) (4.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.8.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.14.0rc1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.11.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.33.4)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.13.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.1.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (3.7.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask->syft) (1.1.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision>=0.3.0->syft) (0.46)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->syft) (0.13.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->syft) (1.3.0)
# Requirement already satisfied: python-engineio>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from python-socketio>=2.1.0->flask-socketio->syft) (3.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (3.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow<2,>=1.12.0->tf-encrypted>=0.5.4->syft) (41.0.1)
# WARNING: Logging before flag parsing goes to stderr.
# W0619 06:00:23.246786 139714928109440 secure_random.py:22] Falling back to insecure randomness since the required custom op could not be found for the installed version of TensorFlow (1.14.0-rc1). Fix this by compiling custom ops.
# W0619 06:00:23.270684 139714928109440 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tf_encrypted/session.py:28: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
# check for GPU compatibility
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Load `PUBLIC` and `PRIVATE` datasets with `torchvision`
#
#
# **`PRIVATE DATA`**: **train_data**; This is the dataset we want to anonymize. 10 independent teacher models will be trained on 10 different partitions of this dataset
#
# **`PUBLIC DATA`**: **test_data**; This is the dataset upon which we will assign labels; then retrain a model on top of it and then predict on its subset.

# %%
# batch size
batch_size = 64

# apply data transformation strategies
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])

# download and transform training and test sets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

# %% [markdown]
# ## PREPARE PRIVATE DATA FOR 100 DIFFERENT TEACHERS/MODELS

# %%
##Divide training data among teachers

# number of teachers
num_teachers = 100

# list to store dataloaders
teacher_loaders = []

# data-points per loader
data_size = len(train_data) // num_teachers

# iterate 
for i in range(num_teachers):
    # indices 
    indices = list(range(i*data_size, (i+1) *data_size))
    # subset data acc. to indices
    subset_data = Subset(train_data, indices)
    # convert to dataloader format
    loader = torch.utils.data.DataLoader(subset_data, batch_size=batch_size, num_workers=2)
    teacher_loaders.append(loader)

# %%
teacher_loaders
# Out:
# [<torch.utils.data.dataloader.DataLoader at 0x7f1153d5db38>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d5dc88>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d5dd68>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d5de48>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d5df28>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91048>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91128>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91208>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d912e8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d913c8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d914a8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91588>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91668>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91748>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91828>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91908>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d919e8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91ac8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91ba8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91c88>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91d68>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91e48>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f1153d91f28>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06048>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06128>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06208>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd062e8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd063c8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd064a8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06588>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06668>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06748>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06828>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06908>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd069e8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06ac8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06ba8>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06c88>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06d68>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06e48>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bd06f28>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf048>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf240>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf320>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf400>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf4e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf5c0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf6a0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf780>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf860>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdf940>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfa20>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfb00>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfbe0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfcc0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfda0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdfe80>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcdff60>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4080>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4160>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4240>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4320>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4400>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb44e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb45c0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb46a0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4780>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4860>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4940>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4a20>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4b00>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4be0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4cc0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4da0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4e80>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bcb4f60>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e080>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e160>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e240>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e320>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e400>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e4e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e5c0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e6a0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e780>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e860>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0e940>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0ea20>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0eb00>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0ebe0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0ecc0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0eda0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0ee80>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bc0ef60>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe7080>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe7160>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe7240>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe7320>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe7400>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f114bbe74e0>]

# %%
## DL model

class FCN(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
        
    def forward(self, x):
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        
        return x

# %%
## FUNCTION for calculating accuracy

def evaluate(dataloader, model):
    total, correct = 0, 0
    # iterate over dataloader
    for data in dataloader:
        # capture and move to GPU
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        # predict
        outputs = model(inputs)
        # predicted labels
        _, pred = torch.max(outputs.data, 1)
        # total data points
        total += labels.size(0)
        # correctly predicted
        correct += (pred == labels).sum().item()
    return 100 * (correct / total)

# %%
# models
models = []
# total loss
total_loss = []
# iterate over every teacher data
for t in range(len(teacher_loaders)):
  print("Training TEACHER", t+1)
  # training loss
  teacher_loss = [] 
  # initialize teacher model
  teacher_model = FCN()
  # move model to GPU
  teacher_model.to(device)
  # loss
  criterion = nn.CrossEntropyLoss()
  # optimizer
  opt = optim.SGD(teacher_model.parameters(), lr=0.01)
  # dataloader
  dataloader = teacher_loaders[t]
  for e in range(200):
    running_loss = 0
    # images and labels
    for images, labels in dataloader:
      # migrate to GPU
      images, labels = images.to(device), labels.to(device)
      # zero previous gradients
      opt.zero_grad()
      # make predictions
      outputs = teacher_model(images)
      # calculate loss
      loss = criterion(outputs, labels)
      # backpropagate
      loss.backward()
      # weight update
      opt.step()
      # loss update
      teacher_loss.append(loss.item())
      running_loss += loss.item()
  print("Loss at the end of training teacher model {} is {}".format(t+1, running_loss))
  total_loss.append(teacher_loss[-1])
  models.append(teacher_model)
  teacher_model.eval()
  acc = evaluate(dataloader, teacher_model)
  print("Accuracy for model {} is {}".format(t+1, acc))
  print('='*50)
# Out:
# Training TEACHER 1
# Loss at the end of training teacher model 1 is 0.7232226505875587
# Accuracy for model 1 is 99.16666666666667
# ==================================================
# Training TEACHER 2
# Loss at the end of training teacher model 2 is 0.9969199653714895
# Accuracy for model 2 is 98.33333333333333
# ==================================================
# Training TEACHER 3
# Loss at the end of training teacher model 3 is 0.7994592674076557
# Accuracy for model 3 is 98.5
# ==================================================
# Training TEACHER 4
# Loss at the end of training teacher model 4 is 0.5565047431737185
# Accuracy for model 4 is 99.66666666666667
# ==================================================
# Training TEACHER 5
# Loss at the end of training teacher model 5 is 0.6404769439250231
# Accuracy for model 5 is 99.5
# ==================================================
# Training TEACHER 6
# Loss at the end of training teacher model 6 is 0.567973280325532
# Accuracy for model 6 is 100.0
# ==================================================
# Training TEACHER 7
# Loss at the end of training teacher model 7 is 0.7511247955262661
# Accuracy for model 7 is 99.0
# ==================================================
# Training TEACHER 8
# Loss at the end of training teacher model 8 is 0.5876109655946493
# Accuracy for model 8 is 99.33333333333333
# ==================================================
# Training TEACHER 9
# Loss at the end of training teacher model 9 is 0.7564879879355431
# Accuracy for model 9 is 99.66666666666667
# ==================================================
# Training TEACHER 10
# Loss at the end of training teacher model 10 is 0.6636366471648216
# Accuracy for model 10 is 99.5
# ==================================================
# Training TEACHER 11
# Loss at the end of training teacher model 11 is 0.45825410541146994
# Accuracy for model 11 is 100.0
# ==================================================
# Training TEACHER 12
# Loss at the end of training teacher model 12 is 0.8735346123576164
# Accuracy for model 12 is 98.83333333333333
# ==================================================
# Training TEACHER 13
# Loss at the end of training teacher model 13 is 0.8298545274883509
# Accuracy for model 13 is 98.66666666666667
# ==================================================
# Training TEACHER 14
# Loss at the end of training teacher model 14 is 0.8103007413446903
# Accuracy for model 14 is 99.0
# ==================================================
# Training TEACHER 15
# Loss at the end of training teacher model 15 is 0.9154995996505022
# Accuracy for model 15 is 99.0
# ==================================================
# Training TEACHER 16
# Loss at the end of training teacher model 16 is 0.6557391099631786
# Accuracy for model 16 is 99.16666666666667
# ==================================================
# Training TEACHER 17
# Loss at the end of training teacher model 17 is 0.5758746974170208
# Accuracy for model 17 is 99.83333333333333
# ==================================================
# Training TEACHER 18
# Loss at the end of training teacher model 18 is 0.5082417447119951
# Accuracy for model 18 is 99.5
# ==================================================
# Training TEACHER 19
# Loss at the end of training teacher model 19 is 0.496721962466836
# Accuracy for model 19 is 99.83333333333333
# ==================================================
# Training TEACHER 20
# Loss at the end of training teacher model 20 is 0.5703714676201344
# Accuracy for model 20 is 99.66666666666667
# ==================================================
# Training TEACHER 21
# Loss at the end of training teacher model 21 is 0.6058869976550341
# Accuracy for model 21 is 99.33333333333333
# ==================================================
# Training TEACHER 22
# Loss at the end of training teacher model 22 is 0.98538001999259
# Accuracy for model 22 is 99.0
# ==================================================
# Training TEACHER 23
# Loss at the end of training teacher model 23 is 0.6697918958961964
# Accuracy for model 23 is 98.83333333333333
# ==================================================
# Training TEACHER 24
# Loss at the end of training teacher model 24 is 1.1038460843265057
# Accuracy for model 24 is 98.5
# ==================================================
# Training TEACHER 25
# Loss at the end of training teacher model 25 is 0.7014259230345488
# Accuracy for model 25 is 99.5
# ==================================================
# Training TEACHER 26
# Loss at the end of training teacher model 26 is 0.9221597611904144
# Accuracy for model 26 is 98.83333333333333
# ==================================================
# Training TEACHER 27
# Loss at the end of training teacher model 27 is 0.8295978233218193
# Accuracy for model 27 is 98.83333333333333
# ==================================================
# Training TEACHER 28
# Loss at the end of training teacher model 28 is 0.7545329555869102
# Accuracy for model 28 is 99.5
# ==================================================
# Training TEACHER 29
# Loss at the end of training teacher model 29 is 0.7011976800858974
# Accuracy for model 29 is 99.66666666666667
# ==================================================
# Training TEACHER 30
# Loss at the end of training teacher model 30 is 1.0390411652624607
# Accuracy for model 30 is 98.5
# ==================================================
# Training TEACHER 31
# Loss at the end of training teacher model 31 is 0.45191336050629616
# Accuracy for model 31 is 100.0
# ==================================================
# Training TEACHER 32
# Loss at the end of training teacher model 32 is 0.5023382697254419
# Accuracy for model 32 is 100.0
# ==================================================
# Training TEACHER 33
# Loss at the end of training teacher model 33 is 0.5918566705659032
# Accuracy for model 33 is 99.66666666666667
# ==================================================
# Training TEACHER 34
# Loss at the end of training teacher model 34 is 0.7258732058107853
# Accuracy for model 34 is 99.0
# ==================================================
# Training TEACHER 35
# Loss at the end of training teacher model 35 is 1.0039749555289745
# Accuracy for model 35 is 98.33333333333333
# ==================================================
# Training TEACHER 36
# Loss at the end of training teacher model 36 is 0.523040471598506
# Accuracy for model 36 is 99.5
# ==================================================
# Training TEACHER 37
# Loss at the end of training teacher model 37 is 0.41202298272401094
# Accuracy for model 37 is 100.0
# ==================================================
# Training TEACHER 38
# Loss at the end of training teacher model 38 is 0.7307919971644878
# Accuracy for model 38 is 98.83333333333333
# ==================================================
# Training TEACHER 39
# Loss at the end of training teacher model 39 is 0.5523628760129213
# Accuracy for model 39 is 99.33333333333333
# ==================================================
# Training TEACHER 40
# Loss at the end of training teacher model 40 is 0.6611391678452492
# Accuracy for model 40 is 99.5
# ==================================================
# Training TEACHER 41
# Loss at the end of training teacher model 41 is 0.5990305915474892
# Accuracy for model 41 is 99.16666666666667
# ==================================================
# Training TEACHER 42
# Loss at the end of training teacher model 42 is 0.7434049546718597
# Accuracy for model 42 is 99.33333333333333
# ==================================================
# Training TEACHER 43
# Loss at the end of training teacher model 43 is 0.7588364668190479
# Accuracy for model 43 is 99.16666666666667
# ==================================================
# Training TEACHER 44
# Loss at the end of training teacher model 44 is 0.9683372005820274
# Accuracy for model 44 is 98.33333333333333
# ==================================================
# Training TEACHER 45
# Loss at the end of training teacher model 45 is 1.045649567618966
# Accuracy for model 45 is 98.83333333333333
# ==================================================
# Training TEACHER 46
# Loss at the end of training teacher model 46 is 0.5447471830993891
# Accuracy for model 46 is 99.33333333333333
# ==================================================
# Training TEACHER 47
# Loss at the end of training teacher model 47 is 0.5873872339725494
# Accuracy for model 47 is 99.66666666666667
# ==================================================
# Training TEACHER 48
# Loss at the end of training teacher model 48 is 0.7605319712311029
# Accuracy for model 48 is 99.16666666666667
# ==================================================
# Training TEACHER 49
# Loss at the end of training teacher model 49 is 0.8117740601301193
# Accuracy for model 49 is 99.5
# ==================================================
# Training TEACHER 50
# Loss at the end of training teacher model 50 is 0.945279847830534
# Accuracy for model 50 is 98.83333333333333
# ==================================================
# Training TEACHER 51
# Loss at the end of training teacher model 51 is 0.8067544139921665
# Accuracy for model 51 is 99.5
# ==================================================
# Training TEACHER 52
# Loss at the end of training teacher model 52 is 0.899805087596178
# Accuracy for model 52 is 98.66666666666667
# ==================================================
# Training TEACHER 53
# Loss at the end of training teacher model 53 is 1.0628967061638832
# Accuracy for model 53 is 97.83333333333334
# ==================================================
# Training TEACHER 54
# Loss at the end of training teacher model 54 is 0.6858094986528158
# Accuracy for model 54 is 98.33333333333333
# ==================================================
# Training TEACHER 55
# Loss at the end of training teacher model 55 is 0.639578546397388
# Accuracy for model 55 is 99.16666666666667
# ==================================================
# Training TEACHER 56
# Loss at the end of training teacher model 56 is 0.6096301209181547
# Accuracy for model 56 is 99.5
# ==================================================
# Training TEACHER 57
# Loss at the end of training teacher model 57 is 0.4594767391681671
# Accuracy for model 57 is 99.83333333333333
# ==================================================
# Training TEACHER 58
# Loss at the end of training teacher model 58 is 0.7318172678351402
# Accuracy for model 58 is 99.33333333333333
# ==================================================
# Training TEACHER 59
# Loss at the end of training teacher model 59 is 0.6902997381985188
# Accuracy for model 59 is 99.5
# ==================================================
# Training TEACHER 60
# Loss at the end of training teacher model 60 is 0.6894186809659004
# Accuracy for model 60 is 98.83333333333333
# ==================================================
# Training TEACHER 61
# Loss at the end of training teacher model 61 is 0.5910996533930302
# Accuracy for model 61 is 99.5
# ==================================================
# Training TEACHER 62
# Loss at the end of training teacher model 62 is 0.5570023506879807
# Accuracy for model 62 is 99.33333333333333
# ==================================================
# Training TEACHER 63
# Loss at the end of training teacher model 63 is 0.7189572975039482
# Accuracy for model 63 is 99.5
# ==================================================
# Training TEACHER 64
# Loss at the end of training teacher model 64 is 0.8477769531309605
# Accuracy for model 64 is 99.0
# ==================================================
# Training TEACHER 65
# Loss at the end of training teacher model 65 is 0.7461545355618
# Accuracy for model 65 is 99.0
# ==================================================
# Training TEACHER 66
# Loss at the end of training teacher model 66 is 0.6963245272636414
# Accuracy for model 66 is 99.66666666666667
# ==================================================
# Training TEACHER 67
# Loss at the end of training teacher model 67 is 0.5837456714361906
# Accuracy for model 67 is 99.66666666666667
# ==================================================
# Training TEACHER 68
# Loss at the end of training teacher model 68 is 0.7084961999207735
# Accuracy for model 68 is 98.83333333333333
# ==================================================
# Training TEACHER 69
# Loss at the end of training teacher model 69 is 0.6742800567299128
# Accuracy for model 69 is 99.33333333333333
# ==================================================
# Training TEACHER 70
# Loss at the end of training teacher model 70 is 0.6796774622052908
# Accuracy for model 70 is 99.83333333333333
# ==================================================
# Training TEACHER 71
# Loss at the end of training teacher model 71 is 0.7374770846217871
# Accuracy for model 71 is 98.83333333333333
# ==================================================
# Training TEACHER 72
# Loss at the end of training teacher model 72 is 0.8024074304848909
# Accuracy for model 72 is 98.66666666666667
# ==================================================
# Training TEACHER 73
# Loss at the end of training teacher model 73 is 0.6062808781862259
# Accuracy for model 73 is 99.66666666666667
# ==================================================
# Training TEACHER 74
# Loss at the end of training teacher model 74 is 0.7264713477343321
# Accuracy for model 74 is 99.0
# ==================================================
# Training TEACHER 75
# Loss at the end of training teacher model 75 is 0.8734745774418116
# Accuracy for model 75 is 98.5
# ==================================================
# Training TEACHER 76
# Loss at the end of training teacher model 76 is 0.7316230684518814
# Accuracy for model 76 is 99.0
# ==================================================
# Training TEACHER 77
# Loss at the end of training teacher model 77 is 0.7656699940562248
# Accuracy for model 77 is 99.5
# ==================================================
# Training TEACHER 78
# Loss at the end of training teacher model 78 is 0.8954142555594444
# Accuracy for model 78 is 98.83333333333333
# ==================================================
# Training TEACHER 79
# Loss at the end of training teacher model 79 is 0.736477879807353
# Accuracy for model 79 is 99.16666666666667
# ==================================================
# Training TEACHER 80
# Loss at the end of training teacher model 80 is 0.52112718205899
# Accuracy for model 80 is 99.33333333333333
# ==================================================
# Training TEACHER 81
# Loss at the end of training teacher model 81 is 0.6338918022811413
# Accuracy for model 81 is 99.83333333333333
# ==================================================
# Training TEACHER 82
# Loss at the end of training teacher model 82 is 0.8078374098986387
# Accuracy for model 82 is 99.0
# ==================================================
# Training TEACHER 83
# Loss at the end of training teacher model 83 is 1.0002558063715696
# Accuracy for model 83 is 98.66666666666667
# ==================================================
# Training TEACHER 84
# Loss at the end of training teacher model 84 is 1.019211295992136
# Accuracy for model 84 is 97.83333333333334
# ==================================================
# Training TEACHER 85
# Loss at the end of training teacher model 85 is 0.7355389948934317
# Accuracy for model 85 is 99.0
# ==================================================
# Training TEACHER 86
# Loss at the end of training teacher model 86 is 0.6589738056063652
# Accuracy for model 86 is 99.16666666666667
# ==================================================
# Training TEACHER 87
# Loss at the end of training teacher model 87 is 0.6868761535733938
# Accuracy for model 87 is 99.0
# ==================================================
# Training TEACHER 88
# Loss at the end of training teacher model 88 is 0.7027396392077208
# Accuracy for model 88 is 98.33333333333333
# ==================================================
# Training TEACHER 89
# Loss at the end of training teacher model 89 is 0.7780716698616743
# Accuracy for model 89 is 99.16666666666667
# ==================================================
# Training TEACHER 90
# Loss at the end of training teacher model 90 is 0.785044502466917
# Accuracy for model 90 is 98.33333333333333
# ==================================================
# Training TEACHER 91
# Loss at the end of training teacher model 91 is 0.7054627239704132
# Accuracy for model 91 is 98.83333333333333
# ==================================================
# Training TEACHER 92
# Loss at the end of training teacher model 92 is 0.6224019844084978
# Accuracy for model 92 is 99.66666666666667
# ==================================================
# Training TEACHER 93
# Loss at the end of training teacher model 93 is 0.6870947387069464
# Accuracy for model 93 is 99.33333333333333
# ==================================================
# Training TEACHER 94
# Loss at the end of training teacher model 94 is 0.4586665201932192
# Accuracy for model 94 is 99.83333333333333
# ==================================================
# Training TEACHER 95
# Loss at the end of training teacher model 95 is 0.6482487469911575
# Accuracy for model 95 is 98.83333333333333
# ==================================================
# Training TEACHER 96
# Loss at the end of training teacher model 96 is 0.6274908063933253
# Accuracy for model 96 is 99.16666666666667
# ==================================================
# Training TEACHER 97
# Loss at the end of training teacher model 97 is 0.6143697202205658
# Accuracy for model 97 is 99.16666666666667
# ==================================================
# Training TEACHER 98
# Loss at the end of training teacher model 98 is 0.27314393781125546
# Accuracy for model 98 is 100.0
# ==================================================
# Training TEACHER 99
# Loss at the end of training teacher model 99 is 0.2362391296774149
# Accuracy for model 99 is 99.83333333333333
# ==================================================
# Training TEACHER 100
# Loss at the end of training teacher model 100 is 0.4521949980407953
# Accuracy for model 100 is 99.66666666666667
# ==================================================

# %%
plt.plot(total_loss)
plt.show()

# %%
models
# Out:
# [FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  ), FCN(
#    (fc1): Linear(in_features=784, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=10, bias=True)
#  )]

# %% [markdown]
# ## Public Dataset

# %%
## Data will be labelled with laplacian noise to anonymize private data
## Unlabelled data-points will be labelled by an aggregating all teacher models
## New DL model will be trained on this labelled data
student_train_data = Subset(test_data, list(range(9000)))
student_train_loader = torch.utils.data.DataLoader(student_train_data, batch_size=batch_size, 
            num_workers=4)


## TEST DATA WHERE WE MAKE FINAL PREDICTIONS 
## ACCURACY WILL BE MEASURED
student_test_data = Subset(test_data, list(range(9000, 10000)))
student_test_loader = torch.utils.data.DataLoader(student_test_data, batch_size=batch_size, 
            num_workers=4)

# %%
## PREDICT WITH DL MODEL function

def predict(model, dataloader):
    
    outputs = torch.zeros(0, dtype=torch.long).to(device)
    # migrate to GPU
    model.to(device)
    # set to evaluation mode
    model.eval()
    # true labels
    true_labels = torch.zeros(0, dtype=torch.long).to(device)
    # iterate over batch
    for images, labels in dataloader:
        # migrate to GPU
        images, labels = images.to(device), labels.to(device)
        # predict
        output = model(images)
        # pick up index with max. value
        ps = torch.argmax(torch.exp(output), dim=1)
        # append to "outputs" torch array
        outputs = torch.cat((outputs, ps))
        true_labels = torch.cat((true_labels, labels))
    
    return outputs, true_labels

# %% [markdown]
# ## ADD LAPLACIAN NOISE AND AGGREGRATE MODELS
#
# STEPS:
# - Make predictions for each of the 10 models on the unlabelled public data i.e. `student_train_loader`.
# - Find out predicted labels and add **laplacian noise** for a certain **epsilon-delta** constraint for generating new labels.

# %%
# list to store predictions on unlabelled public data
preds = torch.torch.zeros((len(models), 9000), dtype=torch.long)
gt_labels = torch.torch.zeros((len(models), 9000), dtype=torch.long)

# iterate
for i, model in enumerate(models):
    # predict on unlabelled public data
    pred, true_labels = predict(model, student_train_loader)
    preds[i] = pred
    gt_labels[i] = true_labels

    

# list to store new labels post laplacian noise addition
labels = []


for pred in preds.transpose(1,0):
    
    # value counts for every label
    label_counts = np.bincount(pred, minlength=10)
    # calculate beta
    beta = 1 / 0.35                                # (epsilon=0.1)
    # iterate to add laplacian noise
    for i in range(len(label_counts)):
        label_counts[i] += np.random.laplace(0, beta, 1)
    
    # catch image with max occurence
    new_label = np.argmax(label_counts)
    # add to list
    labels.append(new_label)

# %%
print(preds, type(preds))
print(labels, type(labels))
print(gt_labels, type(gt_labels))
# Out:
# tensor([[7, 5, 1,  ..., 6, 9, 0],
#         [7, 5, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0],
#         ...,
#         [7, 2, 1,  ..., 6, 9, 0],
#         [7, 8, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0]]) <class 'torch.Tensor'>
# [7, 2, 1, 0, 4, 1, 4, 9, 6, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 1, 3, 1, 3, 6, 7, 2, 7, 1, 2, 1, 1, 7, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 8, 4, 2, 7, 4, 2, 4, 3, 0, 7, 0, 2, 7, 1, 7, 3, 7, 9, 7, 9, 6, 2, 7, 8, 4, 7, 5, 6, 1, 3, 6, 9, 3, 1, 4, 1, 1, 6, 9, 6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 1, 3, 9, 7, 4, 4, 4, 9, 2, 5, 4, 7, 6, 9, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1, 7, 1, 8, 2, 0, 4, 9, 9, 5, 5, 1, 5, 6, 0, 3, 4, 4, 6, 5, 4, 6, 5, 4, 5, 1, 4, 4, 7, 3, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 3, 0, 1, 1, 1, 0, 9, 0, 5, 1, 6, 4, 2, 3, 6, 1, 1, 1, 3, 9, 5, 2, 9, 4, 5, 9, 3, 9, 0, 3, 5, 5, 5, 7, 2, 2, 7, 1, 2, 8, 4, 1, 7, 3, 3, 8, 7, 7, 7, 2, 2, 4, 1, 5, 8, 8, 4, 2, 5, 0, 4, 4, 2, 4, 1, 9, 5, 7, 7, 2, 8, 2, 0, 8, 3, 7, 7, 9, 1, 8, 1, 8, 0, 3, 0, 1, 9, 9, 4, 1, 8, 2, 1, 2, 9, 7, 5, 9, 2, 6, 4, 1, 5, 4, 2, 9, 2, 0, 4, 0, 0, 2, 3, 1, 7, 1, 2, 9, 0, 2, 9, 4, 3, 3, 0, 0, 5, 1, 9, 6, 4, 2, 5, 7, 7, 9, 3, 5, 4, 2, 0, 7, 1, 1, 2, 1, 5, 3, 3, 9, 7, 8, 6, 3, 4, 1, 3, 8, 1, 0, 5, 1, 7, 1, 5, 0, 6, 1, 8, 5, 1, 7, 9, 4, 6, 7, 2, 5, 0, 6, 5, 6, 3, 7, 2, 0, 8, 8, 5, 9, 1, 1, 4, 0, 7, 3, 7, 6, 1, 6, 2, 1, 9, 2, 8, 6, 1, 9, 5, 2, 5, 4, 4, 2, 8, 3, 9, 2, 4, 0, 0, 3, 1, 7, 7, 3, 7, 9, 7, 1, 9, 2, 1, 4, 2, 9, 2, 0, 4, 9, 1, 4, 8, 1, 8, 4, 5, 9, 8, 8, 3, 7, 6, 0, 0, 3, 5, 8, 0, 6, 4, 8, 5, 3, 3, 2, 3, 9, 1, 2, 5, 8, 0, 5, 6, 6, 6, 3, 8, 8, 2, 9, 5, 8, 9, 6, 1, 8, 4, 1, 2, 8, 3, 1, 9, 7, 5, 4, 0, 9, 9, 9, 1, 0, 5, 2, 3, 7, 0, 9, 4, 0, 6, 3, 9, 3, 2, 1, 3, 1, 5, 6, 5, 7, 8, 2, 2, 2, 8, 6, 6, 5, 4, 8, 9, 7, 1, 5, 0, 3, 8, 3, 1, 9, 6, 4, 4, 6, 4, 1, 1, 8, 2, 5, 4, 8, 3, 4, 0, 0, 2, 3, 2, 9, 1, 0, 6, 7, 4, 4, 7, 9, 6, 9, 0, 9, 8, 0, 9, 6, 0, 6, 5, 5, 4, 8, 3, 3, 9, 3, 3, 8, 7, 8, 0, 2, 2, 1, 7, 0, 6, 5, 4, 3, 3, 0, 9, 6, 5, 8, 0, 9, 9, 6, 8, 6, 8, 5, 7, 3, 6, 0, 2, 4, 0, 2, 8, 3, 1, 9, 7, 5, 8, 0, 8, 4, 6, 2, 6, 7, 9, 9, 6, 9, 8, 2, 2, 9, 2, 7, 3, 5, 9, 1, 8, 0, 2, 0, 5, 2, 1, 3, 7, 6, 7, 1, 2, 5, 8, 0, 3, 5, 9, 4, 0, 9, 1, 8, 6, 7, 1, 4, 3, 4, 9, 1, 4, 5, 1, 7, 3, 9, 7, 6, 9, 1, 3, 2, 8, 3, 3, 6, 9, 2, 4, 7, 8, 5, 1, 1, 4, 4, 3, 1, 0, 7, 7, 0, 7, 9, 9, 4, 8, 5, 5, 4, 0, 5, 2, 1, 6, 8, 4, 8, 0, 4, 0, 6, 1, 7, 3, 8, 6, 7, 2, 6, 9, 3, 1, 4, 6, 8, 5, 9, 8, 0, 6, 2, 1, 7, 3, 4, 1, 0, 5, 4, 3, 1, 1, 7, 4, 9, 9, 9, 8, 4, 0, 2, 4, 5, 1, 1, 6, 4, 7, 1, 9, 4, 2, 4, 1, 5, 5, 3, 5, 3, 1, 4, 5, 6, 8, 9, 4, 1, 9, 3, 8, 0, 3, 2, 5, 1, 2, 5, 3, 4, 4, 0, 8, 8, 3, 3, 1, 2, 3, 5, 9, 6, 3, 2, 6, 1, 3, 6, 0, 7, 2, 1, 7, 1, 4, 2, 4, 2, 1, 7, 9, 6, 1, 1, 2, 4, 3, 1, 7, 7, 4, 7, 0, 7, 3, 1, 3, 1, 0, 7, 7, 0, 3, 5, 3, 2, 7, 6, 6, 9, 2, 8, 3, 5, 2, 2, 5, 6, 0, 8, 2, 9, 2, 8, 6, 8, 8, 7, 9, 9, 3, 0, 6, 6, 3, 2, 1, 3, 2, 2, 9, 3, 0, 0, 5, 1, 8, 1, 4, 9, 6, 0, 2, 9, 1, 4, 7, 4, 7, 3, 9, 8, 8, 4, 7, 1, 2, 1, 2, 2, 3, 7, 3, 2, 3, 9, 1, 1, 4, 0, 3, 5, 5, 8, 6, 3, 0, 6, 7, 6, 6, 3, 2, 7, 9, 1, 1, 2, 5, 6, 4, 9, 5, 2, 3, 3, 5, 7, 8, 9, 1, 1, 0, 9, 1, 4, 4, 5, 4, 0, 6, 2, 2, 3, 1, 5, 1, 2, 0, 3, 8, 1, 2, 6, 7, 1, 6, 2, 3, 9, 0, 1, 2, 2, 0, 8, 9, 7, 0, 2, 3, 1, 9, 7, 8, 1, 0, 4, 1, 9, 9, 5, 4, 2, 6, 8, 1, 3, 7, 5, 4, 4, 1, 8, 1, 3, 8, 1, 2, 6, 8, 0, 6, 2, 1, 1, 7, 1, 5, 3, 4, 6, 9, 5, 0, 9, 2, 6, 4, 8, 2, 1, 7, 2, 4, 9, 4, 4, 0, 9, 9, 2, 2, 3, 3, 4, 3, 5, 7, 3, 5, 8, 1, 2, 4, 4, 6, 4, 9, 3, 1, 0, 6, 9, 5, 9, 5, 9, 7, 3, 8, 0, 3, 0, 1, 3, 6, 7, 2, 5, 9, 7, 9, 6, 3, 6, 3, 7, 4, 6, 5, 8, 5, 4, 7, 8, 8, 8, 0, 7, 6, 8, 9, 7, 3, 7, 1, 9, 5, 2, 7, 3, 5, 1, 1, 2, 1, 4, 7, 4, 7, 5, 4, 5, 4, 0, 8, 3, 6, 9, 6, 0, 2, 7, 4, 4, 4, 4, 6, 6, 4, 7, 9, 3, 4, 5, 5, 8, 7, 3, 9, 2, 7, 0, 2, 4, 1, 1, 1, 6, 9, 2, 8, 7, 2, 0, 1, 5, 6, 4, 1, 9, 0, 6, 0, 4, 6, 5, 1, 5, 0, 8, 3, 2, 2, 3, 6, 2, 1, 6, 1, 1, 3, 7, 7, 0, 8, 0, 5, 4, 0, 6, 8, 2, 2, 3, 8, 4, 0, 4, 6, 5, 5, 1, 2, 1, 3, 1, 7, 9, 6, 7, 2, 0, 0, 5, 8, 6, 6, 5, 4, 1, 9, 3, 1, 5, 8, 1, 0, 2, 4, 4, 3, 6, 8, 8, 6, 9, 0, 4, 0, 4, 4, 7, 9, 3, 4, 1, 5, 9, 2, 3, 5, 8, 8, 0, 5, 3, 5, 6, 6, 0, 1, 6, 0, 3, 7, 4, 4, 1, 2, 9, 1, 4, 6, 9, 9, 3, 9, 8, 4, 4, 5, 1, 3, 1, 5, 8, 7, 9, 4, 8, 6, 2, 9, 9, 1, 9, 5, 6,  ...
# tensor([[7, 2, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0],
#         ...,
#         [7, 2, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0],
#         [7, 2, 1,  ..., 6, 9, 0]]) <class 'torch.Tensor'>

# %%
# convert to NumPy arrays
labels = np.array(labels)
preds = preds.numpy()

# %%
# How many labels are intact even after noise addition?
(gt_labels[0].cpu().numpy() == labels).sum()
# Out:
# 8053

# %% [markdown]
# ## Perform PATE Analysis

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=labels, noise_eps=0.35, delta=1e-5)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# ...
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# l too large to compute sensitivity
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data Independent Epsilon: 4421.512925464969
# Data Dependent Epsilon: 1.4391471864907415

# %% [markdown]
# ## Training on student data
#
# This time we will be training a new DL on `student_train_loader`

# %%
labels
# Out:
# array([7, 2, 1, ..., 6, 9, 0])

# %%
# model
student_model = FCN()
# migrate to GPU
student_model.to(device)
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
opt = optim.SGD(student_model.parameters(), lr=0.1)
# no. of epochs
epochs = 100
# tracking params
epoch_loss = []

for e in range(epochs):
    running_loss = 0
    # model in training mode, dropout is on
    student_model.train()
    # load data 
    for idx, (images, _) in enumerate(student_train_loader):
        true_labels = labels[idx*len(images):(idx+1)*len(images)]
        images, true_labels = images.to(device), torch.Tensor(true_labels).to(device).long()
        # make gradients zero
        opt.zero_grad()
        # predict
        output = student_model(images)
        # calculate loss
        loss = criterion(output, true_labels)
        # backpropagate
        loss.backward()
        # update weights
        opt.step()
        # append loss
        running_loss += loss.item()
    epoch_loss.append(running_loss)
    print("Training loss at epoch {} is {}".format(e+1, running_loss))
    print('='*100)
# Out:
# Training loss at epoch 1 is 212.77050504088402
# ====================================================================================================
# Training loss at epoch 2 is 83.34444814920425
# ====================================================================================================
# Training loss at epoch 3 is 53.37647370249033
# ====================================================================================================
# Training loss at epoch 4 is 39.16846489533782
# ====================================================================================================
# Training loss at epoch 5 is 35.38218763098121
# ====================================================================================================
# Training loss at epoch 6 is 29.591793671250343
# ====================================================================================================
# Training loss at epoch 7 is 27.223193358629942
# ====================================================================================================
# Training loss at epoch 8 is 25.212445382028818
# ====================================================================================================
# Training loss at epoch 9 is 23.490475792437792
# ====================================================================================================
# Training loss at epoch 10 is 22.328172005712986
# ====================================================================================================
# Training loss at epoch 11 is 19.838830169290304
# ====================================================================================================
# Training loss at epoch 12 is 18.067570310086012
# ====================================================================================================
# Training loss at epoch 13 is 18.521013107150793
# ====================================================================================================
# Training loss at epoch 14 is 17.435640193521976
# ====================================================================================================
# Training loss at epoch 15 is 14.758690237998962
# ====================================================================================================
# Training loss at epoch 16 is 14.216056197881699
# ====================================================================================================
# Training loss at epoch 17 is 14.204647313803434
# ====================================================================================================
# Training loss at epoch 18 is 15.702207703143358
# ====================================================================================================
# Training loss at epoch 19 is 13.310277532786131
# ====================================================================================================
# Training loss at epoch 20 is 11.586790699511766
# ====================================================================================================
# Training loss at epoch 21 is 10.177849013358355
# ====================================================================================================
# Training loss at epoch 22 is 16.741362761706114
# ====================================================================================================
# Training loss at epoch 23 is 13.47845596075058
# ====================================================================================================
# Training loss at epoch 24 is 12.076559372246265
# ====================================================================================================
# Training loss at epoch 25 is 8.997584130614996
# ====================================================================================================
# Training loss at epoch 26 is 8.525228012353182
# ====================================================================================================
# Training loss at epoch 27 is 7.206254929304123
# ====================================================================================================
# Training loss at epoch 28 is 7.437335975468159
# ====================================================================================================
# Training loss at epoch 29 is 18.448761891573668
# ====================================================================================================
# Training loss at epoch 30 is 9.783761035650969
# ====================================================================================================
# Training loss at epoch 31 is 13.417182579636574
# ====================================================================================================
# Training loss at epoch 32 is 6.598996229469776
# ====================================================================================================
# Training loss at epoch 33 is 6.4652468003332615
# ====================================================================================================
# Training loss at epoch 34 is 4.748698215931654
# ====================================================================================================
# Training loss at epoch 35 is 4.703973777592182
# ====================================================================================================
# Training loss at epoch 36 is 4.56214527413249
# ====================================================================================================
# Training loss at epoch 37 is 6.652402102947235
# ====================================================================================================
# Training loss at epoch 38 is 16.576896026730537
# ====================================================================================================
# Training loss at epoch 39 is 13.680244900286198
# ====================================================================================================
# Training loss at epoch 40 is 5.482889004051685
# ====================================================================================================
# Training loss at epoch 41 is 4.311526577919722
# ====================================================================================================
# Training loss at epoch 42 is 3.6974683552980423
# ====================================================================================================
# Training loss at epoch 43 is 4.23993806540966
# ====================================================================================================
# Training loss at epoch 44 is 6.110413052141666
# ====================================================================================================
# Training loss at epoch 45 is 2.8661844953894615
# ====================================================================================================
# Training loss at epoch 46 is 2.7244137041270733
# ====================================================================================================
# Training loss at epoch 47 is 2.094019617885351
# ====================================================================================================
# Training loss at epoch 48 is 2.6649485863745213
# ====================================================================================================
# Training loss at epoch 49 is 1.8526051715016365
# ====================================================================================================
# Training loss at epoch 50 is 1.7099405862390995
# ====================================================================================================
# Training loss at epoch 51 is 1.4617393091320992
# ====================================================================================================
# Training loss at epoch 52 is 1.5305196568369865
# ====================================================================================================
# Training loss at epoch 53 is 1.361789621412754
# ====================================================================================================
# Training loss at epoch 54 is 22.714472867548466
# ====================================================================================================
# Training loss at epoch 55 is 14.141177169978619
# ====================================================================================================
# Training loss at epoch 56 is 4.179905921220779
# ====================================================================================================
# Training loss at epoch 57 is 2.7946774810552597
# ====================================================================================================
# Training loss at epoch 58 is 1.902989849448204
# ====================================================================================================
# Training loss at epoch 59 is 1.704611036926508
# ====================================================================================================
# Training loss at epoch 60 is 1.6738786920905113
# ====================================================================================================
# Training loss at epoch 61 is 1.2857149578630924
# ====================================================================================================
# Training loss at epoch 62 is 22.99922890588641
# ====================================================================================================
# Training loss at epoch 63 is 4.227595627307892
# ====================================================================================================
# Training loss at epoch 64 is 3.464033231139183
# ====================================================================================================
# Training loss at epoch 65 is 2.015402838587761
# ====================================================================================================
# Training loss at epoch 66 is 2.670138631016016
# ====================================================================================================
# Training loss at epoch 67 is 2.5526579171419144
# ====================================================================================================
# Training loss at epoch 68 is 1.1115409843623638
# ====================================================================================================
# Training loss at epoch 69 is 1.0316894054412842
# ====================================================================================================
# Training loss at epoch 70 is 1.065552294254303
# ====================================================================================================
# Training loss at epoch 71 is 1.0276952311396599
# ====================================================================================================
# Training loss at epoch 72 is 0.8629140593111515
# ====================================================================================================
# Training loss at epoch 73 is 0.7537687309086323
# ====================================================================================================
# Training loss at epoch 74 is 0.820202499628067
# ====================================================================================================
# Training loss at epoch 75 is 0.6287982724606991
# ====================================================================================================
# Training loss at epoch 76 is 0.5267250835895538
# ====================================================================================================
# Training loss at epoch 77 is 0.5914052426815033
# ====================================================================================================
# Training loss at epoch 78 is 0.5543784275650978
# ====================================================================================================
# Training loss at epoch 79 is 1.8602389097213745
# ====================================================================================================
# Training loss at epoch 80 is 0.9930132515728474
# ====================================================================================================
# Training loss at epoch 81 is 0.5171595141291618
# ====================================================================================================
# Training loss at epoch 82 is 28.96747301891446
# ====================================================================================================
# Training loss at epoch 83 is 6.614982757717371
# ====================================================================================================
# Training loss at epoch 84 is 4.920174513012171
# ====================================================================================================
# Training loss at epoch 85 is 1.8389692567288876
# ====================================================================================================
# Training loss at epoch 86 is 1.2657982409000397
# ====================================================================================================
# Training loss at epoch 87 is 0.6891934797167778
# ====================================================================================================
# Training loss at epoch 88 is 0.8956817090511322
# ====================================================================================================
# Training loss at epoch 89 is 0.6963811963796616
# ====================================================================================================
# Training loss at epoch 90 is 0.6792188212275505
# ====================================================================================================
# Training loss at epoch 91 is 0.4566948637366295
# ====================================================================================================
# Training loss at epoch 92 is 0.42699894681572914
# ====================================================================================================
# Training loss at epoch 93 is 0.4336087480187416
# ====================================================================================================
# Training loss at epoch 94 is 0.6699607372283936
# ====================================================================================================
# Training loss at epoch 95 is 8.787434834986925
# ====================================================================================================
# Training loss at epoch 96 is 6.117338307201862
# ====================================================================================================
# Training loss at epoch 97 is 1.7885245755314827
# ====================================================================================================
# Training loss at epoch 98 is 1.4861608296632767
# ====================================================================================================
# Training loss at epoch 99 is 0.7841131053864956
# ====================================================================================================
# Training loss at epoch 100 is 1.075403567403555
# ====================================================================================================

# %% [markdown]
# ## TEST ON STUDENT DATA i.e. `student_test_loader`

# %%
print(evaluate(student_test_loader, student_model))
# Out:
# 87.2
